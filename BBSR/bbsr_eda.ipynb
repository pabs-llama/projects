# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import statistics as st
import seaborn as sns
import datetime 
import os
import sqlite3
import chardet
from sqlite3 import Error
from sqlalchemy import create_engine

# %%
# detect files encoding
with open("OBD_2024_I_2025-03-13T14_15_26.csv", "rb") as f:
    result = chardet.detect(f.read(100000))  # Read first 100,000 bytes
    print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7295400999999999, 'language': ''}

# %%
oko_df = pd.read_csv("OBD_2024_I_2025-03-13T14_15_26.csv", delimiter=";", encoding = result["encoding"], low_memory=False)

# %%
oko_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16701 entries, 0 to 16700
# Data columns (total 81 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   UUID                                           16701 non-null  object
#  1   Version                                        16701 non-null  object
#  2   Name (de)                                      14451 non-null  object
#  3   Name (en)                                      16661 non-null  object
#  4   Kategorie (original)                           16701 non-null  object
#  5   Kategorie (en)                                 16701 non-null  object
#  6   Konformität                                    16701 non-null  object
#  7   Laenderkennung                                 16698 non-null  object
#  8   Typ                                            16701 non-null  object
# ...

# %%
oko_df.head()
# Out:
#                                    UUID    Version  \
# 0  7e88f530-2367-463a-a7fd-b87c19b0884e  00.00.015
# 1  7e88f530-2367-463a-a7fd-b87c19b0884e  00.00.015
# 2  7e88f530-2367-463a-a7fd-b87c19b0884e  00.00.015
# 3  7e88f530-2367-463a-a7fd-b87c19b0884e  00.00.015
# 4  7e88f530-2367-463a-a7fd-b87c19b0884e  00.00.015
#
#                                       Name (de) Name (en)  \
# 0  Initiative Ziegel Österreich - Tondachziegel       NaN
# 1  Initiative Ziegel Österreich - Tondachziegel       NaN
# 2  Initiative Ziegel Österreich - Tondachziegel       NaN
# 3  Initiative Ziegel Österreich - Tondachziegel       NaN
# 4  Initiative Ziegel Österreich - Tondachziegel       NaN
#
#                                 Kategorie (original)  \
# 0  'Mineralische Baustoffe' / 'Steine und Element...
# 1  'Mineralische Baustoffe' / 'Steine und Element...
# 2  'Mineralische Baustoffe' / 'Steine und Element...
# 3  'Mineralische Baustoffe' / 'Steine und Element...
# ...
