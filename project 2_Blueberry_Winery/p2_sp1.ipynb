# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import statistics as st

red_wines = pd.read_csv("winequality-red.csv", sep = ";")
white_wines = pd.read_csv("winequality-white.csv", sep =";")

# %% [markdown]
# # DATA WRANGLING

# %%
red_wines.head(10)
# red_wines.tail(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white_wines.head(10)
# white_wines.tail(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
red_wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None

# %%
print(white_wines.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# None

# %%
red_wines.shape
# Out:
# (1599, 12)

# %%
white_wines.shape
# Out:
# (4898, 12)

# %% [markdown]
# ## NULL VALUES

# %%
white_wines.isna().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
red_wines.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# ## DESCRIPTIVE STADISTICS

# %%
red_wines.describe().round(2)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        1599.00           1599.00      1599.00         1599.00
# mean            8.32              0.53         0.27            2.54
# std             1.74              0.18         0.19            1.41
# min             4.60              0.12         0.00            0.90
# 25%             7.10              0.39         0.09            1.90
# 50%             7.90              0.52         0.26            2.20
# 75%             9.20              0.64         0.42            2.60
# max            15.90              1.58         1.00           15.50
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    1599.00              1599.00               1599.00  1599.00  1599.00
# mean        0.09                15.87                 46.47     1.00     3.31
# std         0.05                10.46                 32.90     0.00     0.15
# ...

# %%
white_wines.describe().round(2)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        4898.00           4898.00      4898.00         4898.00
# mean            6.85              0.28         0.33            6.39
# std             0.84              0.10         0.12            5.07
# min             3.80              0.08         0.00            0.60
# 25%             6.30              0.21         0.27            1.70
# 50%             6.80              0.26         0.32            5.20
# 75%             7.30              0.32         0.39            9.90
# max            14.20              1.10         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density       pH  \
# count    4898.00              4898.00               4898.00  4898.00  4898.00
# mean        0.05                35.31                138.36     0.99     3.19
# std         0.02                17.01                 42.50     0.00     0.15
# ...

# %%
red_wines ['quality_label'] = red_wines['quality'].apply(lambda value: 'low' if value <= 5 
                                                        else 'medium' if value <= 7 
                                                        else 'high')

red_wines['quality_label'] = pd.Categorical(red_wines['quality_label'],
categories=['low', 'medium', 'high'])

white_wines ['quality_label'] = white_wines['quality'].apply(lambda value: 'low' if value <= 5 
                                                        else 'medium' if value <= 7 
                                                        else 'high')

white_wines["quality_label"] = pd.Categorical(white_wines["quality_label"], categories = ["low","medium","high"])

# %% [markdown]
# # MERGED DATASETS

# %%
white_and_red = pd.merge(red_wines, white_wines, how = "outer")
white_and_red.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            3.8             0.310         0.02           11.10      0.036
# 1            3.9             0.225         0.40            4.20      0.030
# 2            4.2             0.170         0.36            1.80      0.029
# 3            4.2             0.215         0.23            5.10      0.041
# 4            4.4             0.320         0.39            4.30      0.030
# 5            4.4             0.460         0.10            2.80      0.024
# 6            4.4             0.540         0.09            5.10      0.038
# 7            4.5             0.190         0.21            0.95      0.033
# 8            4.6             0.445         0.00            1.40      0.053
# 9            4.6             0.520         0.15            2.10      0.054
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# # CONCAT

# %%
white_and_red_concat = pd.concat([red_wines[["residual sugar","total sulfur dioxide", "sulphates", "alcohol","volatile acidity","quality"]].describe(), 
            white_wines[["residual sugar","total sulfur dioxide", "sulphates", "alcohol","volatile acidity","quality"]].describe()], 
            axis=1, 
            keys=["Red Wines Stats", "White Wines Stats"])

white_and_red_concat.round(2)



# residual sugar and total sulfur dioxide is almost 3x in white wine
# sulphates are slightly higer on red wine
# lvl of alc is similar on both
# volatale acidity is way higher in red wine
# white wine has slightly higher avg quality
# Out:
#       Red Wines Stats                                          \
#        residual sugar total sulfur dioxide sulphates  alcohol
# count         1599.00              1599.00   1599.00  1599.00
# mean             2.54                46.47      0.66    10.42
# std              1.41                32.90      0.17     1.07
# min              0.90                 6.00      0.33     8.40
# 25%              1.90                22.00      0.55     9.50
# 50%              2.20                38.00      0.62    10.20
# 75%              2.60                62.00      0.73    11.10
# max             15.50               289.00      2.00    14.90
#
#                                 White Wines Stats                       \
#       volatile acidity  quality    residual sugar total sulfur dioxide
# count          1599.00  1599.00           4898.00              4898.00
# mean              0.53     5.64              6.39               138.36
# ...

# %%
count_red = white_and_red_concat[[("Red Wines Stats", "residual sugar"),("White Wines Stats", "residual sugar")]]

count_red


fig, ax_lst =   plt.plot()
ax_lst.pie( count, )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[109], line 6
#       1 count_red = white_and_red_concat[[("Red Wines Stats", "residual sugar"),("White Wines Stats", "residual sugar")]]
#       3 count_red
# ----> 6 fig, ax_lst =   plt.plot()
#       7 ax_lst.pie(count)
#
# ValueError: not enough values to unpack (expected 2, got 0)
