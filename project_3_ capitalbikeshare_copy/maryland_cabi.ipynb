# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import statistics as st
import seaborn as sns
import datetime 
from geopy import distance
import folium
from folium.plugins import MarkerCluster
from folium.features import GeoJsonTooltip
from branca.colormap import LinearColormap
from collections import Counter
import json
from shapely.geometry import Point
import geopandas as gpd
from shapely.geometry import shape

# %%
data_types = {
    "rideable_type": "category", 
    "start_station_name": "category", 
    "end_station_name": "category", 
    "member_casual":"category",
    # "ride_id":"uint32",
    "time_of_day":"category",
    "trip_type":"category"}

# %%
rides_maryland = pd.read_csv("cabi_maryland.csv", dtype = data_types, parse_dates= ["started_at", "ended_at"], low_memory=False)

# %%
with open ("Maryland_Physical_Boundaries_-_County_Boundaries_(Detailed).geojson") as i:
    maryland = json.loads(i.read())

features = maryland["features"]

#GDF
maryland_gdf = gpd.GeoDataFrame(
    pd.DataFrame([feature['properties'] for feature in features]),  # Extract properties as attributes
    geometry=[shape(feature['geometry']) for feature in features],  # Convert geometries
    crs="EPSG:4326")

# %% [markdown]
# # join gdf and filter maryland rides

# %%
# # Create a GeoDataFrame for the start stations
# geometry = [Point(xy) for xy in zip(rides_maryland['start_lng'], rides_maryland['start_lat'])]
# bikes_gdf = gpd.GeoDataFrame(rides_maryland, geometry=geometry, crs="EPSG:4326")

# # # Perform spatial join with the maryland gdf
# bikes_maryland_join = gpd.sjoin(bikes_gdf, maryland_gdf, how="left", predicate="within")

# %%
# rides_maryland = bikes_maryland_join.dropna(subset="COUNTY")

# %%
# rides_maryland = rides_maryland.copy()

# %%
# rides_maryland['year'] = rides_maryland['started_at'].dt.year
# rides_maryland['dow'] = rides_maryland['started_at'].dt.dayofweek
# rides_maryland["weekday"] = rides_maryland["started_at"].dt.day_name()

# %%
# rides_maryland = rides_maryland.drop(columns= ['index_right','OBJECTID','DISTRICT', 'COUNTY_FIP', 'COUNTYNUM','CREATION_D', 'LAST_UPDAT'])

# %%
# # Count rides per county
rides_per_county = rides_maryland.groupby("COUNTY").size().reset_index(name="ride_count")  
rides_per_county
# Out:
#             COUNTY  ride_count
# 0       Montgomery      168967
# 1  Prince George's       74195

# %%
# # Convert 'weekday' to a categorical type with the correct order
weekday_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
# rides_maryland["weekday"] = pd.Categorical(rides_maryland["weekday"], categories=weekday_order, ordered=True)

# %%
# rides_maryland.to_csv("cabi_maryland.csv", index=False)

# %% [markdown]
# # filtering per year

# %%
year_2021= rides_maryland[rides_maryland["year"]==2021]
year_2022= rides_maryland[rides_maryland["year"]==2022]
rides_maryland_2023= rides_maryland[rides_maryland["year"]==2023]

# %%
rides_maryland["year"].value_counts()
# Out:
# year
# 2023    98071
# 2021    72587
# 2022    72504
# Name: count, dtype: int64

# %% [markdown]
# # filtering unique stations (classic and docked ebikes) from undocked e-bikes

# %%
# unique_station_coordinates.groupby("start_station_name")["start_lat"].mean()
avg_lat_per_station = rides_maryland.groupby("start_station_name", as_index=False, observed=False)["start_lat"].mean()
avg_lng_per_station = rides_maryland.groupby("start_station_name", as_index=False, observed = False)["start_lng"].mean()

maryland_unique_bike_stations = avg_lat_per_station.merge(avg_lng_per_station)
maryland_unique_bike_stations = maryland_unique_bike_stations.dropna(subset="start_lat")
maryland_unique_bike_stations
# Out:
#                 start_station_name  start_lat  start_lng
# 5              10th & Monroe St NE  38.973495 -77.020706
# 8                   10th & U St NW  38.983053 -76.998549
# 14                  11th & C St SE  39.000126 -77.079726
# 15            11th & Clifton St NW  39.012635 -77.066359
# 21                  11th & O St NW  39.012635 -77.066359
# ..                             ...        ...        ...
# 850  Wisconsin Ave & Ingomar St NW  39.012635 -77.066359
# 851   Wisconsin Ave & Newark St NW  38.931240 -76.951919
# 853   Wisconsin Ave & Rodman St NW  38.989793 -77.028654
# 855   Woodglen Dr & Executive Blvd  39.043182 -77.113494
# 857   Woodmont Ave & Strathmore St  38.979872 -77.093512
#
# [198 rows x 3 columns]

# %%
rides_maryland_2023["rideable_type"].value_counts()
# Out:
# rideable_type
# electric_bike    48641
# classic_bike     46467
# docked_bike       2963
# Name: count, dtype: int64

# %%
undocked_bikes = rides_maryland_2023[rides_maryland_2023["rideable_type"] == "electric_bike" ]

# %%
undocked_bikes["started_at"].dt.date.nunique()
# Out:
# 365

# %%
# Count rides per weekday
rides_per_day = undocked_bikes["weekday"].value_counts().sort_index()

# Calculate average rides per weekday
# nunique() gives the number of unique dates in the dataset.
# Count how many times each weekday appears in the dataset
unique_dates = undocked_bikes["started_at"].dt.date.unique()  # Get all unique dates
dates_df = pd.DataFrame({"date": unique_dates})  # Convert to DataFrame
dates_df["weekday"] = pd.to_datetime(dates_df["date"]).dt.day_name()  # Extract weekday
dates_df["weekday"] = pd.Categorical(dates_df["weekday"], categories=weekday_order, ordered=True)
days_per_weekday = dates_df["weekday"].value_counts().sort_index()

# %%
days_per_weekday
# Out:
# weekday
# Monday       52
# Tuesday      52
# Wednesday    52
# Thursday     52
# Friday       52
# Saturday     52
# Sunday       53
# Name: count, dtype: int64

# %%
# Can also just divide by number of weeks in a year (52) 
average_rides = rides_per_day / days_per_weekday # weeks in a year / undocked_bikes["started_at"].dt.date.nunique()
print("Average undocked rides in Maryland for each day of the week in 2023",average_rides)
# Out:
# Average undocked rides in Maryland for each day of the week in 2023 weekday
# Monday       126.750000
# Tuesday      138.057692
# Wednesday    136.307692
# Thursday     136.961538
# Friday       134.192308
# Saturday     133.769231
# Sunday       126.924528
# Name: count, dtype: float64

# %%
sns.barplot(x=average_rides.index, y=average_rides.values, palette="coolwarm", hue=average_rides.index)
# Out:
# <Axes: xlabel='weekday'>

# %% [markdown]
# undocked bikes shows rides, not stations. can think of a timelapse per hour to see how the bikes are placed at a given time. Mapping all the undocled ebikes in a year at once will give the impression there are lot more in circulation than they actually are

# %% [markdown]
# # choosing a Random day to check the bikes distribution on a map

# %%
# sampling a random date
random_date = np.random.choice(undocked_bikes["started_at"].dt.date.unique())
print(f"Randomly selected date: {random_date}")

# Filter dataset for the chosen date
random_day = undocked_bikes[undocked_bikes["started_at"].dt.date == pd.to_datetime(random_date).date()]
# Out:
# Randomly selected date: 2023-05-16

# %%
#REVIEW - should i consider all ebikes as being dockless? 
# half of them have info on start station, which could indicate that they were left near a station, but not docked

# keeping only rides without bike stations to account for undocked bikes
# random_day[random_day["start_station_name"].isna()]
random_day
# Out:
#          ride_id  rideable_type          started_at            ended_at  \
# 7519139  7519140  electric_bike 2023-05-16 00:26:35 2023-05-16 00:30:23
# 7519173  7519174  electric_bike 2023-05-16 00:53:01 2023-05-16 01:10:02
# 7519174  7519175  electric_bike 2023-05-16 00:53:07 2023-05-16 01:08:47
# 7519239  7519240  electric_bike 2023-05-16 02:26:18 2023-05-16 02:26:49
# 7519241  7519242  electric_bike 2023-05-16 02:27:52 2023-05-16 03:07:34
# ...          ...            ...                 ...                 ...
# 7532357  7532358  electric_bike 2023-05-16 22:46:06 2023-05-16 22:51:47
# 7532547  7532548  electric_bike 2023-05-16 23:27:14 2023-05-17 00:14:20
# 7532550  7532551  electric_bike 2023-05-16 23:29:11 2023-05-16 23:38:54
# 7532552  7532553  electric_bike 2023-05-16 23:29:39 2023-05-16 23:48:50
# 7532628  7532629  electric_bike 2023-05-16 23:52:19 2023-05-17 00:05:30
#
#                                start_station_name start_station_id  \
# 7519139                    West Hyattsville Metro            32418
# 7519173  Silver Spring Transit Center - Top Level            32034
# 7519174  Silver Spring Transit Center - Top Level            32034
# 7519239                                       NaN            31806
# 7519241                                       NaN            31806
# ...                                           ...              ...
# 7532357                                       NaN            31806
# 7532547                Citadel Ave & McGrath Blvd            32076
# 7532550  Silver Spring Transit Center - Top Level            32034
# 7532552                Battery Ln & Trolley Trail            32027
# 7532628                                       NaN            32418
#
#                    end_station_name end_station_id member_casual  start_lat  \
# 7519139                         NaN          32418        casual  38.955336
# 7519173      10th St & Spring Rd NW          31426        member  38.994032
# 7519174                         NaN          31229        member  38.994036
# 7519239                         NaN          31806        casual  38.850000
# 7519241                         NaN          31806        casual  38.850000
# ...                             ...            ...           ...        ...
# 7532357           Anacostia Library          31804        casual  38.850000
# 7532547                         NaN          32078        casual  39.048992
# 7532550                         NaN          31515        member  38.994066
# 7532552  Battery Ln & Trolley Trail          32027        casual  38.992402
# 7532628                         NaN          32418        casual  38.970000
#
#          ...  end_hour  trip_duration_minutes  time_of_day  \
# 7519139  ...         0                    4.0        night
# 7519173  ...         1                   17.0        night
# 7519174  ...         1                   16.0        night
# 7519239  ...         2                    1.0        night
# 7519241  ...         3                   40.0        night
# ...      ...       ...                    ...          ...
# 7532357  ...        22                    6.0        night
# 7532547  ...         0                   47.0        night
# 7532550  ...        23                   10.0        night
# 7532552  ...        23                   19.0        night
# 7532628  ...         0                   13.0        night
#
#                            geometry           COUNTY  Shape_Length  \
# 7519139  POINT (-76.96806 38.95534)  Prince George's      3.427406
# 7519173  POINT (-77.03042 38.99403)       Montgomery      4.104648
# 7519174  POINT (-77.03042 38.99404)       Montgomery      4.104648
# 7519239        POINT (-76.96 38.85)  Prince George's      3.427406
# 7519241        POINT (-76.96 38.85)  Prince George's      3.427406
# ...                             ...              ...           ...
# 7532357        POINT (-76.96 38.85)  Prince George's      3.427406
# 7532547  POINT (-77.10937 39.04899)       Montgomery      4.104648
# 7532550  POINT (-77.03044 38.99407)       Montgomery      4.104648
# 7532552   POINT (-77.10015 38.9924)       Montgomery      4.104648
# 7532628           POINT (-77 38.97)       Montgomery      4.104648
#
#          Shape_Area  year dow  weekday
# 7519139    0.130280  2023   1  Tuesday
# 7519173    0.134082  2023   1  Tuesday
# 7519174    0.134082  2023   1  Tuesday
# 7519239    0.130280  2023   1  Tuesday
# 7519241    0.130280  2023   1  Tuesday
# ...             ...   ...  ..      ...
# 7532357    0.130280  2023   1  Tuesday
# 7532547    0.134082  2023   1  Tuesday
# 7532550    0.134082  2023   1  Tuesday
# 7532552    0.134082  2023   1  Tuesday
# 7532628    0.134082  2023   1  Tuesday
#
# [138 rows x 26 columns]

# %%
random_day_gdf = random_day.copy()

# %%
random_day_gdf = random_day_gdf.drop(columns=["started_at", "ended_at"])

# %%
avg_lat = random_day["start_lat"].mean()
avg_lng = random_day["start_lng"].mean()

maryland_map= folium.Map(location=[avg_lat, avg_lng],   
                zoom_start=12,              
                max_zoom=26,               
                min_zoom=2)  

# marker_cluster = MarkerCluster(name= "E-bikes").add_to(maryland_map)

# %%
l1 = folium.GeoJson(
    random_day_gdf,  
    overlay= True, 
    control = True,
    show = True,
    name= "E-bikes",
    marker=folium.CircleMarker(radius=4, fill_color="white", fill_opacity=1, color="black", weight=1),
    tooltip=folium.GeoJsonTooltip(fields=["start_station_name"],
                                  aliases=["Station: "]),
    popup=folium.GeoJsonPopup(fields=["start_station_name"]),
    highlight_function=lambda x: {"fillOpacity": 0.8},
    zoom_on_click=False,
).add_to(maryland_map)

# %%
maryland_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59cd769a02a413cb0ef23b76cb3ac6a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59cd769a02a413cb0ef23b76cb3ac6a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59cd769a02a413cb0ef23b76cb3ac6a2 = L.map(
#                 &quot;map_59cd769a02a413cb0ef23b76cb3ac6a2&quot;,
#                 {
#                     center: [38.97055854952657, -77.02301101360145],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7490b6d4c8086bf11848b75d86c8881 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 2,
#   &quot;maxZoom&quot;: 26,
#   &quot;maxNativeZoom&quot;: 26,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7490b6d4c8086bf11848b75d86c8881.addTo(map_59cd769a02a413cb0ef23b76cb3ac6a2);
#
#
#         function geo_json_b1a10ab65fb6052b8be170cd5f35beca_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8};
#             }
#         }
#         function geo_json_b1a10ab65fb6052b8be170cd5f35beca_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 1};
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b1a10ab65fb6052b8be170cd5f35beca_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b1a10ab65fb6052b8be170cd5f35beca.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b1a10ab65fb6052b8be170cd5f35beca_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b1a10ab65fb6052b8be170cd5f35beca = L.geoJson(null, {
#                 onEachFeature: geo_json_b1a10ab65fb6052b8be170cd5f35beca_onEachFeature,
#
#                 pointToLayer: geo_json_b1a10ab65fb6052b8be170cd5f35beca_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_b1a10ab65fb6052b8be170cd5f35beca_add (data) {
#             geo_json_b1a10ab65fb6052b8be170cd5f35beca
#                 .addData(data);
#         }
#             geo_json_b1a10ab65fb6052b8be170cd5f35beca_add({&quot;bbox&quot;: [-77.171633, 38.782681, -76.913115382, 39.119804], &quot;features&quot;: [{&quot;bbox&quot;: [-76.968059778, 38.955335975, -76.968059778, 38.955335975], &quot;geometry&quot;: {&quot;coordinates&quot;: [-76.968059778, 38.955335975], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7519139&quot;, &quot;properties&quot;: {&quot;COUNTY&quot;: &quot;Prince George\u0027s&quot;, &quot;Shape_Area&quot;: 0.13027954846216314, &quot;Shape_Length&quot;: 3.427406275726167, &quot;dow&quot;: 1, &quot;end_hour&quot;: 0, &quot;end_lat&quot;: 38.96, &quot;end_lng&quot;: -76.97, &quot;end_station_id&quot;: &quot;32418&quot;, &quot;end_station_name&quot;: null, &quot;end_time&quot;: &quot;00:30:23&quot;, &quot;member_casual&quot;: &quot;casual&quot;, &quot;ride_id&quot;: 7519140, &quot;rideable_type&quot;: &quot;electric_bike&quot;, &quot;start_hour&quot;: 0, &quot;start_lat
